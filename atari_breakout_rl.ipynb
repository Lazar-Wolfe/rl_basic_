# %% [markdown]
# # Atari on Windows
# https://github.com/openai/gym/issues/1726#issuecomment-550580367

# %%
# !pip3 install stable-baselines3[extra]
# !pip3 install numpy

# %%
import atari_py
print(atari_py.list_games())
# Out:
# ['tetris']

# %%
import os
import gym 
from stable_baselines3 import A2C
from stable_baselines3.common.vec_env import VecFrameStack # training on multiple env at the same time
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_atari_env

# %% [markdown]
# Installing Atari Games<br />
# http://www.atarimania.com/roms/Roms.rar

# %%
environment_name = 'Breakout-v0'
env = gym.make(environment_name,render_mode='rgb_array')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14696\2651710534.py in <module>
#       1 environment_name = 'Breakout-v0'
# ----> 2 env = gym.make(environment_name,render_mode='rgb_array')
#
# c:\Python\Python39\lib\site-packages\gym\envs\registration.py in make(id, **kwargs)
#     233
#     234 def make(id, **kwargs):
# --> 235     return registry.make(id, **kwargs)
#     236
#     237
#
# c:\Python\Python39\lib\site-packages\gym\envs\registration.py in make(self, path, **kwargs)
#     127             logger.info("Making new env: %s", path)
#     128         spec = self.spec(path)
# --> 129         env = spec.make(**kwargs)
#     130         return env
#     131
#
# c:\Python\Python39\lib\site-packages\gym\envs\registration.py in make(self, **kwargs)
#      87             env = self.entry_point(**_kwargs)
#      88         else:
# ...

# %%
env.close()

# %%
env.reset()

# %%
env.action_space

# %%
env.observation_space

# %%
episodes = 5
env = gym.make(environment_name)
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()

# %%
env = make_atari_env(environment_name, n_envs=4,seed=0)
env = VecFrameStack(env,n_stack=4)

# %%
log_path = os.path.join('Training','Logs')
model = A2C('CnnPolicy',env,verbose=1,tensorboard_log=log_path)

# %%
model.learn(total_timesteps=200000)
