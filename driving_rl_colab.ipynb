# %% [markdown]
# <a href="https://colab.research.google.com/github/Lazar-Wolfe/rl_basic_/blob/main/driving_rl_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install Swig version 3.0.12 <br>
# Install atarimania roms http://www.atarimania.com/roms/Roms.rar

# %% [markdown]
# https://www.gymlibrary.ml/environments/box2d/car_racing/

# %%
# !pip3 install stable_baselines3[extra]
# !pip3 install gym[box2d] pyglet

# %%
# !apt install xvfb -y
# !pip install pyvirtualdisplay
# !pip install piglet

from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()

# %%
import gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack,DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
environment_name = 'CarRacing-v0'
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Track generation: 1067..1338 -> 271-tiles track
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-c07c36362924> in <module>()
#       1 episodes = 5
#       2 for episode in range(1, episodes+1):
# ----> 3     state = env.reset()
#       4     done = False
#       5     score = 0
#
# /usr/local/lib/python3.7/dist-packages/gym/wrappers/time_limit.py in reset(self, **kwargs)
#      25         return self.env.reset(**kwargs)
#
# /usr/local/lib/python3.7/dist-packages/gym/envs/box2d/car_racing.py in reset(self)
#     363
#     364         return self.step(None)[0]
# --> 365
#     366     def step(self, action):
#     367         if action is not None:
#
# /usr/local/lib/python3.7/dist-packages/gym/envs/box2d/car_racing.py in step(self, action)
#     375
#     376         self.state = self.render("state_pixels")
# --> 377
#     378         step_reward = 0
#     379         done = False
#
# /usr/local/lib/python3.7/dist-packages/gym/envs/box2d/car_racing.py in render(self, mode)
#     398         if self.viewer is None:
#     399             from gym.envs.classic_control import rendering
# --> 400
#     401             self.viewer = rendering.Viewer(WINDOW_W, WINDOW_H)
#     402             self.score_label = pyglet.text.Label(
#
# /usr/local/lib/python3.7/dist-packages/gym/envs/classic_control/rendering.py in <module>()
#      23
#      24 try:
# ---> 25     from pyglet.gl import *
#      26 except ImportError as e:
#      27     raise ImportError('''
#
# /usr/local/lib/python3.7/dist-packages/pyglet/gl/__init__.py in <module>()
#     233 elif compat_platform == 'darwin':
#     234     from .cocoa import CocoaConfig as Config
# --> 235 del base  # noqa: F821
#     236
#     237
#
# NameError: name 'base' is not defined

# %%
env.close()

# %%
env.action_space.sample()
# Out:
# array([0.13876769, 0.08316862, 0.09994502], dtype=float32)

# %%
env.action_space
# Out:
# Box([-1.  0.  0.], [1. 1. 1.], (3,), float32)

# %%
env.observation_space
# will be an image 96,96,3

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])

# %%
log_path = os.path.join('Training', 'Logs')

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
PATH = F"/content/gdrive/My Drive/Racing_rl"

# %%
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log=PATH)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=50000)
# Out:
# Track generation: 1229..1540 -> 311-tiles track
# Logging to /content/gdrive/My Drive/Racing_rl/PPO_2
# Track generation: 1115..1404 -> 289-tiles track
# Track generation: 1159..1453 -> 294-tiles track
# -----------------------------
# | time/              |      |
# |    fps             | 91   |
# |    iterations      | 1    |
# |    time_elapsed    | 22   |
# |    total_timesteps | 2048 |
# -----------------------------

# %%
# ppo_path = os.path.join('Training', 'Saved Models', 'PPO_Driving_model')
ppo_path = F"/content/gdrive/My Drive/Racing_rl_model"
model.save(ppo_path)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# Track generation: 1222..1532 -> 310-tiles track
# Track generation: 1072..1344 -> 272-tiles track
# Track generation: 1184..1484 -> 300-tiles track
# Track generation: 1207..1513 -> 306-tiles track
# Track generation: 1361..1705 -> 344-tiles track
# Track generation: 1075..1353 -> 278-tiles track
# Track generation: 1280..1604 -> 324-tiles track
# Track generation: 1248..1567 -> 319-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1266..1587 -> 321-tiles track
# Track generation: 992..1244 -> 252-tiles track
# Track generation: 1183..1483 -> 300-tiles track
# Track generation: 1021..1285 -> 264-tiles track
# (-23.345074471086264, 14.391685602063168)

# %%
env.close()

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()

# %%
env.close()
